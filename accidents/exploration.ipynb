# %%
import pandas as pd

# %%
data = pd.read_csv('accidents-corporels-de-la-circulation.csv', sep=';')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 58 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Identifiant de l'accident           423 non-null    int64
#  1   Date et heure                       423 non-null    object
#  2   Commune                             417 non-null    object
#  3   Année                               423 non-null    int64
#  4   Mois                                423 non-null    int64
#  5   Jour                                423 non-null    int64
#  6   Heure minute                        423 non-null    object
#  7   Lumière                             423 non-null    object
#  8   Localisation                        423 non-null    object
#  9   Intersection                        423 non-null    object
#  10  Conditions atmosphériques           423 non-null    object
# ...
