# %%
import pandas as pd

# %%
food = pd.read_csv('food.csv', sep=';', decimal=',')
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469 entries, 0 to 468
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Produit              469 non-null    object
#  1   Type of Food (100g)  469 non-null    object
#  2   Energy (Kcal)        469 non-null    int64
#  3   Protein (g)          469 non-null    float64
#  4   Fat (g)              469 non-null    float64
#  5   Water (g)            469 non-null    float64
#  6   Vitamin A (mg)       469 non-null    int64
#  7   Vitamin B1 (mg)      469 non-null    float64
#  8   Vitamin B2 (mg)      469 non-null    float64
#  9   Vitamin C            469 non-null    float64
#  10  Unnamed: 10          1 non-null      float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 40.4+ KB
