# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import mean_squared_error, root_mean_squared_error
import seaborn as sns

# %%
columns = ['Function Point Count', 'Work Hours', 'Operating System', 'Database Management System', 'Language']
data = pd.read_csv('temps.csv', sep=',' ,names=columns)
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Function Point Count        104 non-null    int64
#  1   Work Hours                  104 non-null    int64
#  2   Operating System            104 non-null    int64
#  3   Database Management System  104 non-null    int64
#  4   Language                    104 non-null    int64
# dtypes: int64(5)
# memory usage: 4.2 KB

# %%
data["Operating System"] = data["Operating System"].astype('category')
data["Database Management System"] = data["Database Management System"].astype('category')
data["Language"] = data["Language"].astype('category')
data.describe(include='all')
# Out:
#         Function Point Count    Work Hours  Operating System  \
# count             104.000000    104.000000             104.0
# unique                   NaN           NaN               2.0
# top                      NaN           NaN               1.0
# freq                     NaN           NaN              60.0
# mean              620.894231   9976.230769               NaN
# std               639.324324  11944.580302               NaN
# min               102.000000    283.000000               NaN
# 25%               205.750000   2234.250000               NaN
# 50%               372.500000   4943.500000               NaN
# 75%               763.000000  14337.250000               NaN
# max              3472.000000  72219.000000               NaN
#
#         Database Management System  Language
# count                        104.0     104.0
# unique                         5.0       4.0
# top                            1.0       1.0
# freq                          37.0      35.0
# ...

# %%
sns.pairplot(data, hue="Database Management System")
